# %% [markdown]
# # 백준1439(그리디),플립문제

# %% [markdown]
# ![image.png](attachment:86e78120-51cb-4268-b5dd-f886db6a7e66.png)

# %% [markdown]
# ![image.png](attachment:08af9144-ae6e-4660-869e-a984ab975d81.png)

# %%
import sys

# data = list(map(int,sys.stdin.readline().strip().split()))

data = list(map(int,input()))
# Out:
#  0001100

# %%
data = list(map(int,input()))
standard = data[0]

count = 0

check = 0

def flip(data):
    
    count = 0 
    result = 0
    change = 0
    

    for i in range(len(data)):

        if i == standard:
            continue

        else: 
            if i+1 == len(data):
                
                break
            
            data[i]=standard
            
            
            
            if data[i] == data[i+1]:
                
                data[i+1]=standard
                change+=1
          
            

#     for i in data:

#         if i != standard:
#             return False

#         else:
#             count+=1
    
#     result = count//len(data)
    
    
    return change
            
        
    

flip(data)
# Out:
#  110011
# 3

# %% [markdown]
# `=` 틀림

# %% [markdown]
# * 생각은 나는데 도저히 코드로 구현을 못하겠던 부분
#
# >  바뀐 횟수를 카운트를 한후 0과1 덩어리를 못 구했다.
#
# ```python
#
# print((cnt+1)//2) -> 이코드를 생각해내지 못했다..
# ```

# %% [markdown]
# `-` 정답 코드

# %%
s = input()

cnt = 0 
for i in range(len(s)-1):
    if s[i] != s[i+1]:
        cnt += 1

print((cnt+1)//2)

# %% [markdown]
# ```python
#
# print((cnt+1)//2)
# ```
#
# * 110011 이때는 덩어리가 ``총 3개`` 이다 즉 ``cnt =2``라는 의미(바뀐횟수는 총 2번 : 1->0, 0->1)
#
# * 그렇기에

# %%
cnt
# Out:
# 3

# %%
4//2
# Out:
# 2
